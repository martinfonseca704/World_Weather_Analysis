# punta arenas cl
# ilulissat gl
# mogwase za
# longyearbyen sj
# cape town za
# punta arenas cl
# los llanos de aridane es
# kodiak us
# rikitea pf
# rocha uy
# vaini to
# tuktoyaktuk ca
# vila franca do campo pt
# illoqqortoormiut gl
# punta arenas cl
# jamestown sh
# santa gertrudis mx
# tiznit ma
# vaitupu wf
# tautira pf
# cape town za
# ushuaia ar
# nanortalik gl
# taolanaro mg
# puerto ayora ec
# mataura pf
# rikitea pf
# kijang id
# barrow us
# busselton au
# surt ly
# tuktoyaktuk ca
# victoria sc
# ushuaia ar
# inderborskiy kz
# atuona pf
# izhma ru
# saldanha za
# shestakovo ru
# khatanga ru
# mataura pf
# mataura pf
# rikitea pf
# kruisfontein za
# namibe ao
# vaini to
# grand river south east mu
# saint george bm
# busselton au
# constantine dz
# cidreira br
# albany au
# nioro ml
# chicama pe
# tiksi ru
# solovetskiy ru
# sao jose da coroa grande br
# port elizabeth za
# warrnambool au
# silikatnyy ru
# beisfjord no
# port elizabeth za
# ulaangom mn
# nadym ru
# iqaluit ca
# castro cl
# aklavik ca
# khatanga ru
# kamenskoye ru
# illoqqortoormiut gl
# moose factory ca
# rikitea pf
# vaini to
# busselton au
# jiddah sa
# butaritari ki
# hambantota lk
# aksu cn
# nikolskoye ru
# tilichiki ru
# faanui pf
# castro cl
# barrow us
# georgetown sh
# kieta pg
# sungai padi th
# dingle ie
# mayor pablo lagerenza py
# luau ao
# busselton au
# bluff nz
# athni in
# tuktoyaktuk ca
# labuhan id
# puerto ayora ec
# novovasylivka ua
# amderma ru
# saint-augustin ca
# midland us
# jardim br
# rikitea pf
# henties bay na
# bandarbeyla so
# chapais ca
# portobelo pa
# mar del plata ar
# dubbo au
# jamestown sh
# rikitea pf
# punta arenas cl
# mataura pf
# bairiki ki
# bom jardim br
# ushuaia ar
# hambantota lk
# kapaa us
# alice springs au
# sorland no
# codrington ag
# gravdal no
# la primavera co
# guerrero negro mx
# kapaa us
# punta arenas cl
# narsaq gl
# hermanus za
# juba sd
# namibe ao
# port elizabeth za
# narsaq gl
# taolanaro mg
# saldanha za
# rikitea pf
# castro cl
# hilo us
# avarua ck
# atuona pf
# albany au
# ribeira grande pt
# rikitea pf
# new norfolk au
# vaini to
# torbay ca
# lebu cl
# mataura pf
# basoko cd
# paragominas br
# qaanaaq gl
# mataura pf
# hermanus za
# wadi musa jo
# chuy uy
# flinders au
# kytlym ru
# muravlenko ru
# bodden town ky
# severo-kurilsk ru
# kavieng pg
# taolanaro mg
# mahajanga mg
# kamenskoye ru
# mataura pf
# carnarvon au
# punta arenas cl
# arraial do cabo br
# okha ru
# pionki pl
# eureka us
# adrar dz
# kiunga pg
# bredasdorp za

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 639

# %%
#6.2.3 Make an API Call

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
#Make an API Call

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f7054cd6957ab15ca4d656804b9ebd38

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f7054cd6957ab15ca4d656804b9ebd38&q=Boston

# %%
#6.2.4 Make a Request for Data to an API

# %%
# Retrieve a Response Using the get() Method

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
city_weather.status_code
# Out:
# 200

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
##Get Data from a Response
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02d"}],"base":"stations","main":{"temp":73.53,"feels_like":74.05,"temp_min":66.94,"temp_max":77.09,"pressure":1015,"humidity":74},"visibility":10000,"wind":{"speed":5.01,"deg":0,"gust":15.01},"clouds":{"all":20},"dt":1658656420,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1658654922,"sunset":1658707948},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 73.53,
#   'feels_like': 74.05,
#   'temp_min': 66.94,
#   'temp_max': 77.09,
#   'pressure': 1015,
#   'humidity': 74},
#  'visibility': 10000,
#  'wind': {'speed': 5.01, 'deg': 0, 'gust': 15.01},
#  'clouds': {'all': 20},
#  'dt': 1658656420,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1658654922,
#   'sunset': 1658707948},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
#Handle Request Errors
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
#6.2.5 Parse a Response from an API

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 73.53,
#   'feels_like': 74.05,
#   'temp_min': 66.94,
#   'temp_max': 77.09,
#   'pressure': 1015,
#   'humidity': 74},
#  'visibility': 10000,
#  'wind': {'speed': 5.01, 'deg': 0, 'gust': 15.01},
#  'clouds': {'all': 20},
#  'dt': 1658656420,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1658654922,
#   'sunset': 1658707948},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data['sys']
# Out:
# {'type': 2,
#  'id': 2013408,
#  'country': 'US',
#  'sunrise': 1658654922,
#  'sunset': 1658707948}

# %%
boston_data['sys']['country']
# Out:
# 'US'

# %%
boston_data['dt']
# Out:
# 1658656420

# %%
boston_data["coord"]["lat"]
# Out:
# 42.3584

# %%
boston_data["main"]["temp_max"]
# Out:
# 77.09

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 77.09 74 20 5.01

# %%
#Convert the Date Timestamp

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2022, 7, 24, 9, 53, 40)

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-07-24 09:53:40'

# %%
#6.2.6 Get the City Weather Data

# %%
#Import Dependencies, and Initialize an Empty List and Counters

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | ambam
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | numan
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | kamenka
# Processing Record 8 of Set 1 | chemax
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | luderitz
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | hutchinson
# Processing Record 14 of Set 1 | xingyi
# Processing Record 15 of Set 1 | mahebourg
# Processing Record 16 of Set 1 | bambous virieux
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | nikolskoye
# Processing Record 19 of Set 1 | ostrovnoy
# Processing Record 20 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 1 | pacifica
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | omaruru
# Processing Record 24 of Set 1 | saint-francois
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | bure
# Processing Record 27 of Set 1 | finote selam
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | sagua la grande
# Processing Record 30 of Set 1 | pauini
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | salalah
# Processing Record 33 of Set 1 | tautira
# Processing Record 34 of Set 1 | necochea
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | vezirkopru
# Processing Record 37 of Set 1 | xuanhua
# Processing Record 38 of Set 1 | ubala
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | yecuatla
# Processing Record 41 of Set 1 | isangel
# Processing Record 42 of Set 1 | san patricio
# Processing Record 43 of Set 1 | baruun-urt
# Processing Record 44 of Set 1 | inta
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | takoradi
# Processing Record 47 of Set 1 | saskylakh
# Processing Record 48 of Set 1 | dangtu
# Processing Record 49 of Set 1 | marawi
# Processing Record 50 of Set 1 | paamiut
# Processing Record 1 of Set 2 | palencia
# Processing Record 2 of Set 2 | puerto escondido
# Processing Record 3 of Set 2 | torbay
# Processing Record 4 of Set 2 | tasiilaq
# Processing Record 5 of Set 2 | dalbandin
# Processing Record 6 of Set 2 | knysna
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | san quintin
# Processing Record 9 of Set 2 | yulara
# Processing Record 10 of Set 2 | provideniya
# Processing Record 11 of Set 2 | khandbari
# Processing Record 12 of Set 2 | tamparan
# Processing Record 13 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 2 | ca mau
# Processing Record 15 of Set 2 | dedza
# Processing Record 16 of Set 2 | beringovskiy
# Processing Record 17 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 2 | linares
# Processing Record 19 of Set 2 | lebu
# Processing Record 20 of Set 2 | cape town
# Processing Record 21 of Set 2 | pevek
# Processing Record 22 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 23 of Set 2 | atar
# Processing Record 24 of Set 2 | hasaki
# Processing Record 25 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 2 | truro
# Processing Record 27 of Set 2 | flin flon
# Processing Record 28 of Set 2 | faanui
# Processing Record 29 of Set 2 | severo-kurilsk
# Processing Record 30 of Set 2 | sibolga
# Processing Record 31 of Set 2 | sicuani
# Processing Record 32 of Set 2 | albany
# Processing Record 33 of Set 2 | fairmont
# Processing Record 34 of Set 2 | upernavik
# Processing Record 35 of Set 2 | hofn
# Processing Record 36 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 2 | harper
# Processing Record 38 of Set 2 | quatre cocos
# Processing Record 39 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 2 | arraial do cabo
# Processing Record 41 of Set 2 | cayenne
# Processing Record 42 of Set 2 | farafangana
# Processing Record 43 of Set 2 | tangping
# Processing Record 44 of Set 2 | fairbanks
# Processing Record 45 of Set 2 | te anau
# Processing Record 46 of Set 2 | coihaique
# Processing Record 47 of Set 2 | hobyo
# Processing Record 48 of Set 2 | chuy
# Processing Record 49 of Set 2 | songjianghe
# Processing Record 50 of Set 2 | olinda
# Processing Record 1 of Set 3 | kankan
# Processing Record 2 of Set 3 | kapaa
# Processing Record 3 of Set 3 | gizo
# Processing Record 4 of Set 3 | joshimath
# Processing Record 5 of Set 3 | souillac
# Processing Record 6 of Set 3 | geraldton
# Processing Record 7 of Set 3 | harda
# Processing Record 8 of Set 3 | clyde river
# Processing Record 9 of Set 3 | raudeberg
# Processing Record 10 of Set 3 | nairn
# Processing Record 11 of Set 3 | qaanaaq
# Processing Record 12 of Set 3 | salto del guaira
# Processing Record 13 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 14 of Set 3 | hermanus
# Processing Record 15 of Set 3 | east london
# Processing Record 16 of Set 3 | snezhnogorsk
# Processing Record 17 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 3 | tsuruoka
# Processing Record 19 of Set 3 | kingman
# Processing Record 20 of Set 3 | calabozo
# Processing Record 21 of Set 3 | ajdabiya
# Processing Record 22 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 3 | badaojiang
# City not found. Skipping...
# Processing Record 25 of Set 3 | cabedelo
# Processing Record 26 of Set 3 | phan thiet
# Processing Record 27 of Set 3 | jamestown
# Processing Record 28 of Set 3 | ribeira grande
# Processing Record 29 of Set 3 | victoria
# Processing Record 30 of Set 3 | zyryanovsk
# Processing Record 31 of Set 3 | stade
# Processing Record 32 of Set 3 | dikson
# Processing Record 33 of Set 3 | paris
# Processing Record 34 of Set 3 | acarau
# Processing Record 35 of Set 3 | butaritari
# Processing Record 36 of Set 3 | concordia
# Processing Record 37 of Set 3 | sisimiut
# Processing Record 38 of Set 3 | gaillac
# Processing Record 39 of Set 3 | new norfolk
# Processing Record 40 of Set 3 | la asuncion
# Processing Record 41 of Set 3 | skegness
# Processing Record 42 of Set 3 | palmer
# Processing Record 43 of Set 3 | vestmanna
# Processing Record 44 of Set 3 | tiksi
# Processing Record 45 of Set 3 | ambovombe
# Processing Record 46 of Set 3 | barrow
# Processing Record 47 of Set 3 | alofi
# Processing Record 48 of Set 3 | taikang
# Processing Record 49 of Set 3 | luanda
# Processing Record 50 of Set 3 | carnarvon
# Processing Record 1 of Set 4 | miri
# Processing Record 2 of Set 4 | broken hill
# Processing Record 3 of Set 4 | batagay-alyta
# Processing Record 4 of Set 4 | fortuna
# Processing Record 5 of Set 4 | nizwa
# Processing Record 6 of Set 4 | alexandria
# Processing Record 7 of Set 4 | yate
# Processing Record 8 of Set 4 | lagoa
# Processing Record 9 of Set 4 | hailey
# Processing Record 10 of Set 4 | haines junction
# Processing Record 11 of Set 4 | homa bay
# Processing Record 12 of Set 4 | pisco
# Processing Record 13 of Set 4 | linchuan
# City not found. Skipping...
# Processing Record 14 of Set 4 | cherskiy
# Processing Record 15 of Set 4 | caravelas
# Processing Record 16 of Set 4 | mangrol
# Processing Record 17 of Set 4 | yiyang
# Processing Record 18 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 19 of Set 4 | maroantsetra
# Processing Record 20 of Set 4 | abu samrah
# Processing Record 21 of Set 4 | opuwo
# Processing Record 22 of Set 4 | tura
# Processing Record 23 of Set 4 | tuktoyaktuk
# Processing Record 24 of Set 4 | hobart
# Processing Record 25 of Set 4 | ponta do sol
# Processing Record 26 of Set 4 | erenhot
# Processing Record 27 of Set 4 | mandiana
# Processing Record 28 of Set 4 | ponta delgada
# Processing Record 29 of Set 4 | biak
# Processing Record 30 of Set 4 | brae
# Processing Record 31 of Set 4 | longyearbyen
# Processing Record 32 of Set 4 | chapais
# Processing Record 33 of Set 4 | kudat
# Processing Record 34 of Set 4 | itarema
# Processing Record 35 of Set 4 | bodden town
# Processing Record 36 of Set 4 | saint george
# Processing Record 37 of Set 4 | kodiak
# Processing Record 38 of Set 4 | hambantota
# Processing Record 39 of Set 4 | amuntai
# Processing Record 40 of Set 4 | san carlos
# Processing Record 41 of Set 4 | qasigiannguit
# Processing Record 42 of Set 4 | chokurdakh
# Processing Record 43 of Set 4 | hebi
# Processing Record 44 of Set 4 | khatanga
# Processing Record 45 of Set 4 | gwadar
# Processing Record 46 of Set 4 | tamworth
# Processing Record 47 of Set 4 | ternate
# Processing Record 48 of Set 4 | rock sound
# Processing Record 49 of Set 4 | piryion
# City not found. Skipping...
# Processing Record 50 of Set 4 | sesheke
# Processing Record 1 of Set 5 | lavrentiya
# Processing Record 2 of Set 5 | milingimbi
# City not found. Skipping...
# Processing Record 3 of Set 5 | havre-saint-pierre
# Processing Record 4 of Set 5 | maarianhamina
# Processing Record 5 of Set 5 | grand gaube
# Processing Record 6 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 5 | masallatah
# Processing Record 8 of Set 5 | bitung
# Processing Record 9 of Set 5 | hirado
# Processing Record 10 of Set 5 | khromtau
# Processing Record 11 of Set 5 | muros
# Processing Record 12 of Set 5 | douglas
# Processing Record 13 of Set 5 | roald
# Processing Record 14 of Set 5 | serik
# Processing Record 15 of Set 5 | kamaishi
# Processing Record 16 of Set 5 | port moresby
# Processing Record 17 of Set 5 | lompoc
# Processing Record 18 of Set 5 | kenora
# Processing Record 19 of Set 5 | mount gambier
# Processing Record 20 of Set 5 | kouango
# Processing Record 21 of Set 5 | price
# Processing Record 22 of Set 5 | korla
# Processing Record 23 of Set 5 | thompson
# Processing Record 24 of Set 5 | kloulklubed
# Processing Record 25 of Set 5 | sikonge
# Processing Record 26 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 5 | kalawit
# Processing Record 28 of Set 5 | mar del plata
# Processing Record 29 of Set 5 | shasta lake
# Processing Record 30 of Set 5 | airai
# Processing Record 31 of Set 5 | pontianak
# Processing Record 32 of Set 5 | viedma
# Processing Record 33 of Set 5 | bengkulu
# Processing Record 34 of Set 5 | ulaangom
# Processing Record 35 of Set 5 | bulgan
# Processing Record 36 of Set 5 | giyani
# Processing Record 37 of Set 5 | ishigaki
# Processing Record 38 of Set 5 | pochutla
# Processing Record 39 of Set 5 | karakol
# Processing Record 40 of Set 5 | vanimo
# Processing Record 41 of Set 5 | indiana
# Processing Record 42 of Set 5 | saldanha
# Processing Record 43 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 5 | narsaq
# Processing Record 45 of Set 5 | ostrogozhsk
# Processing Record 46 of Set 5 | sao joao da barra
# Processing Record 47 of Set 5 | esperance
# Processing Record 48 of Set 5 | abyek
# Processing Record 49 of Set 5 | cidreira
# Processing Record 50 of Set 5 | souris
# Processing Record 1 of Set 6 | honiara
# Processing Record 2 of Set 6 | touros
# Processing Record 3 of Set 6 | san ramon
# Processing Record 4 of Set 6 | gidam
# Processing Record 5 of Set 6 | fengxian
# Processing Record 6 of Set 6 | kruisfontein
# Processing Record 7 of Set 6 | priargunsk
# Processing Record 8 of Set 6 | kalevala
# Processing Record 9 of Set 6 | castro
# Processing Record 10 of Set 6 | coolum beach
# Processing Record 11 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 6 | hanzhong
# Processing Record 13 of Set 6 | preobrazheniye
# Processing Record 14 of Set 6 | boralday
# Processing Record 15 of Set 6 | urumqi
# Processing Record 16 of Set 6 | marzuq
# Processing Record 17 of Set 6 | obukhiv
# Processing Record 18 of Set 6 | puerto ayora
# Processing Record 19 of Set 6 | kavaratti
# Processing Record 20 of Set 6 | cheremshan
# Processing Record 21 of Set 6 | taksimo
# Processing Record 22 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 6 | oranjestad
# Processing Record 24 of Set 6 | jasper
# Processing Record 25 of Set 6 | naze
# Processing Record 26 of Set 6 | nouakchott
# Processing Record 27 of Set 6 | shache
# Processing Record 28 of Set 6 | georgetown
# Processing Record 29 of Set 6 | tuatapere
# Processing Record 30 of Set 6 | shchelyayur
# City not found. Skipping...
# Processing Record 31 of Set 6 | belmonte
# Processing Record 32 of Set 6 | vila franca do campo
# Processing Record 33 of Set 6 | ratnagiri
# Processing Record 34 of Set 6 | mayna
# Processing Record 35 of Set 6 | khonsa
# Processing Record 36 of Set 6 | casablanca
# Processing Record 37 of Set 6 | show low
# Processing Record 38 of Set 6 | rizhao
# Processing Record 39 of Set 6 | pangnirtung
# Processing Record 40 of Set 6 | makat
# Processing Record 41 of Set 6 | aktau
# Processing Record 42 of Set 6 | makasar
# Processing Record 43 of Set 6 | carballo
# Processing Record 44 of Set 6 | sao miguel do araguaia
# Processing Record 45 of Set 6 | port lincoln
# Processing Record 46 of Set 6 | vardo
# Processing Record 47 of Set 6 | suntar
# Processing Record 48 of Set 6 | mayo
# Processing Record 49 of Set 6 | mandalgovi
# Processing Record 50 of Set 6 | escarcega
# Processing Record 1 of Set 7 | saint-philippe
# Processing Record 2 of Set 7 | port hedland
# Processing Record 3 of Set 7 | katsuura
# Processing Record 4 of Set 7 | mago
# Processing Record 5 of Set 7 | nome
# Processing Record 6 of Set 7 | arman
# Processing Record 7 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 7 | paciran
# Processing Record 9 of Set 7 | dunedin
# Processing Record 10 of Set 7 | kantang
# Processing Record 11 of Set 7 | pandan
# Processing Record 12 of Set 7 | dubbo
# Processing Record 13 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 7 | tabou
# Processing Record 15 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 16 of Set 7 | seybaplaya
# Processing Record 17 of Set 7 | ilhabela
# Processing Record 18 of Set 7 | los llanos de aridane
# Processing Record 19 of Set 7 | perry
# Processing Record 20 of Set 7 | kupang
# Processing Record 21 of Set 7 | ginda
# Processing Record 22 of Set 7 | talnakh
# Processing Record 23 of Set 7 | peterhead
# Processing Record 24 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 7 | puerto madryn
# Processing Record 26 of Set 7 | san joaquin
# Processing Record 27 of Set 7 | zyryanka
# Processing Record 28 of Set 7 | kaitangata
# Processing Record 29 of Set 7 | bubaque
# Processing Record 30 of Set 7 | omboue
# Processing Record 31 of Set 7 | sawakin
# Processing Record 32 of Set 7 | manokwari
# Processing Record 33 of Set 7 | amga
# Processing Record 34 of Set 7 | ketchikan
# Processing Record 35 of Set 7 | sao joao de pirabas
# Processing Record 36 of Set 7 | myingyan
# Processing Record 37 of Set 7 | ambon
# Processing Record 38 of Set 7 | bethel
# Processing Record 39 of Set 7 | dongsheng
# Processing Record 40 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 7 | broome
# Processing Record 42 of Set 7 | manjacaze
# Processing Record 43 of Set 7 | chimbote
# Processing Record 44 of Set 7 | nelson bay
# Processing Record 45 of Set 7 | sijunjung
# Processing Record 46 of Set 7 | cabo san lucas
# Processing Record 47 of Set 7 | davila
# Processing Record 48 of Set 7 | phuket
# Processing Record 49 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 7 | arkansas city
# Processing Record 1 of Set 8 | la baneza
# Processing Record 2 of Set 8 | nuevo progreso
# Processing Record 3 of Set 8 | husavik
# Processing Record 4 of Set 8 | ahipara
# Processing Record 5 of Set 8 | gorontalo
# Processing Record 6 of Set 8 | olafsvik
# Processing Record 7 of Set 8 | nouadhibou
# Processing Record 8 of Set 8 | kudahuvadhoo
# Processing Record 9 of Set 8 | tuckahoe
# Processing Record 10 of Set 8 | tilhar
# Processing Record 11 of Set 8 | constitucion
# Processing Record 12 of Set 8 | aquiraz
# Processing Record 13 of Set 8 | bilma
# Processing Record 14 of Set 8 | neuquen
# Processing Record 15 of Set 8 | atbasar
# Processing Record 16 of Set 8 | iqaluit
# Processing Record 17 of Set 8 | colon
# Processing Record 18 of Set 8 | bereda
# Processing Record 19 of Set 8 | terrace
# Processing Record 20 of Set 8 | umea
# Processing Record 21 of Set 8 | mehamn
# Processing Record 22 of Set 8 | kenmare
# Processing Record 23 of Set 8 | nanortalik
# Processing Record 24 of Set 8 | pacific grove
# Processing Record 25 of Set 8 | jacareacanga
# Processing Record 26 of Set 8 | bathsheba
# Processing Record 27 of Set 8 | illapel
# Processing Record 28 of Set 8 | zabaykalsk
# Processing Record 29 of Set 8 | fort nelson
# Processing Record 30 of Set 8 | muisne
# Processing Record 31 of Set 8 | kamarion
# Processing Record 32 of Set 8 | berbera
# Processing Record 33 of Set 8 | kavieng
# Processing Record 34 of Set 8 | norman wells
# Processing Record 35 of Set 8 | alice springs
# Processing Record 36 of Set 8 | araouane
# Processing Record 37 of Set 8 | ous
# Processing Record 38 of Set 8 | jardim
# Processing Record 39 of Set 8 | avera
# Processing Record 40 of Set 8 | suhut
# Processing Record 41 of Set 8 | vitim
# Processing Record 42 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 43 of Set 8 | vao
# Processing Record 44 of Set 8 | tynset
# Processing Record 45 of Set 8 | sinjah
# City not found. Skipping...
# Processing Record 46 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 47 of Set 8 | kamina
# Processing Record 48 of Set 8 | bathurst
# Processing Record 49 of Set 8 | boda
# Processing Record 50 of Set 8 | north bend
# Processing Record 1 of Set 9 | ordynskoye
# Processing Record 2 of Set 9 | daru
# Processing Record 3 of Set 9 | srandakan
# Processing Record 4 of Set 9 | sar-e pul
# Processing Record 5 of Set 9 | pombia
# Processing Record 6 of Set 9 | yukamenskoye
# Processing Record 7 of Set 9 | dwarka
# Processing Record 8 of Set 9 | mazamari
# Processing Record 9 of Set 9 | tukrah
# Processing Record 10 of Set 9 | kafanchan
# Processing Record 11 of Set 9 | jeremie
# Processing Record 12 of Set 9 | dingle
# Processing Record 13 of Set 9 | nabire
# Processing Record 14 of Set 9 | alyangula
# Processing Record 15 of Set 9 | japura
# Processing Record 16 of Set 9 | sao filipe
# Processing Record 17 of Set 9 | dinanagar
# Processing Record 18 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 9 | maumere
# Processing Record 20 of Set 9 | byron bay
# Processing Record 21 of Set 9 | gangotri
# City not found. Skipping...
# Processing Record 22 of Set 9 | henties bay
# Processing Record 23 of Set 9 | itum-kale
# Processing Record 24 of Set 9 | mouzakion
# City not found. Skipping...
# Processing Record 25 of Set 9 | vrangel
# Processing Record 26 of Set 9 | port-gentil
# Processing Record 27 of Set 9 | sitka
# Processing Record 28 of Set 9 | igarka
# Processing Record 29 of Set 9 | manicore
# Processing Record 30 of Set 9 | rio gallegos
# Processing Record 31 of Set 9 | tarija
# Processing Record 32 of Set 9 | sidney
# Processing Record 33 of Set 9 | san cristobal
# Processing Record 34 of Set 9 | jiujiang
# Processing Record 35 of Set 9 | saint-pierre
# Processing Record 36 of Set 9 | nijar
# Processing Record 37 of Set 9 | walvis bay
# Processing Record 38 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 9 | kharp
# Processing Record 40 of Set 9 | yerofey pavlovich
# Processing Record 41 of Set 9 | port macquarie
# Processing Record 42 of Set 9 | urucara
# Processing Record 43 of Set 9 | paracuru
# Processing Record 44 of Set 9 | road town
# Processing Record 45 of Set 9 | gimli
# Processing Record 46 of Set 9 | sept-iles
# Processing Record 47 of Set 9 | fukue
# Processing Record 48 of Set 9 | axim
# Processing Record 49 of Set 9 | anadyr
# Processing Record 50 of Set 9 | mpika
# Processing Record 1 of Set 10 | asyut
# Processing Record 2 of Set 10 | adrar
# Processing Record 3 of Set 10 | gagra
# Processing Record 4 of Set 10 | lixourion
# Processing Record 5 of Set 10 | tosya
# Processing Record 6 of Set 10 | ilulissat
# Processing Record 7 of Set 10 | inderka
# Processing Record 8 of Set 10 | inuvik
# Processing Record 9 of Set 10 | cabra
# Processing Record 10 of Set 10 | durban
# Processing Record 11 of Set 10 | sao jose da coroa grande
# Processing Record 12 of Set 10 | santa maria
# Processing Record 13 of Set 10 | faya
# Processing Record 14 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 15 of Set 10 | oda
# Processing Record 16 of Set 10 | teguise
# Processing Record 17 of Set 10 | puerto ayacucho
# Processing Record 18 of Set 10 | whitehorse
# Processing Record 19 of Set 10 | guerrero negro
# Processing Record 20 of Set 10 | zomin
# Processing Record 21 of Set 10 | mundgod
# Processing Record 22 of Set 10 | peniche
# Processing Record 23 of Set 10 | misasi
# Processing Record 24 of Set 10 | elizabeth city
# Processing Record 25 of Set 10 | erhlin
# City not found. Skipping...
# Processing Record 26 of Set 10 | honningsvag
# Processing Record 27 of Set 10 | kahului
# Processing Record 28 of Set 10 | huilong
# Processing Record 29 of Set 10 | qaqortoq
# Processing Record 30 of Set 10 | laguna
# Processing Record 31 of Set 10 | dire
# Processing Record 32 of Set 10 | port blair
# Processing Record 33 of Set 10 | saleilua
# City not found. Skipping...
# Processing Record 34 of Set 10 | tezu
# Processing Record 35 of Set 10 | acajutla
# Processing Record 36 of Set 10 | wucheng
# Processing Record 37 of Set 10 | ambilobe
# Processing Record 38 of Set 10 | robertsport
# Processing Record 39 of Set 10 | klaksvik
# Processing Record 40 of Set 10 | thaton
# Processing Record 41 of Set 10 | jhang
# Processing Record 42 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 10 | upata
# Processing Record 44 of Set 10 | mayfield
# Processing Record 45 of Set 10 | gat
# Processing Record 46 of Set 10 | kattivakkam
# Processing Record 47 of Set 10 | chimore
# Processing Record 48 of Set 10 | sofiysk
# City not found. Skipping...
# Processing Record 49 of Set 10 | baripada
# Processing Record 50 of Set 10 | clarence town
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [39], in <cell line: 11>()
#      15     set_count += 1
#      16     record_count = 1
# ---> 17     time.sleep(60)
#      19 # Create endpoint URL with each city.
#      20 city_url = url + "&q=" + city.replace(" ","+")
#
# KeyboardInterrupt:

# %%
len(city_data)
# Out:
# 460

# %%
#6.2.7 Create a DataFrame of City Weather Data

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Yellowknife  62.4560 -114.3525     59.52       100          75
# 1           Ambam   2.3833   11.2833     73.56        76          95
# 2            Hilo  19.7297 -155.0900     77.29        94          31
# 3           Numan   9.4667   12.0333     85.32        57          99
# 4         Rikitea -23.1203 -134.9692     73.49        72           6
# 5    Punta Arenas -53.1500  -70.9167     30.31        86           0
# 6         Kamenka  51.3223   42.7678     79.70        47          84
# 7          Chemax  20.6500  -87.9333     73.47        99         100
# 8     Port Alfred -33.5906   26.8910     57.18        92          85
# 9  Port Elizabeth -33.9180   25.5701     61.32        78           0
#
#    Wind Speed Country                 Date
# 0        6.91      CA  2022-07-24 09:57:12
# 1        3.83      CM  2022-07-24 09:57:13
# 2        5.01      US  2022-07-24 09:53:51
# 3       10.25      NG  2022-07-24 09:57:14
# 4       10.33      PF  2022-07-24 09:57:15
# 5        5.75      CL  2022-07-24 09:57:15
# 6        8.30      RU  2022-07-24 09:57:15
# 7        2.77      MX  2022-07-24 09:57:16
# 8        8.99      ZA  2022-07-24 09:57:16
# 9       21.85      ZA  2022-07-24 09:55:58

# %%
# Reorder the column order
new_column_order = ["City", "Country", "Date", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0      Yellowknife      CA  2022-07-24 09:57:12  62.4560 -114.3525     59.52
# 1            Ambam      CM  2022-07-24 09:57:13   2.3833   11.2833     73.56
# 2             Hilo      US  2022-07-24 09:53:51  19.7297 -155.0900     77.29
# 3            Numan      NG  2022-07-24 09:57:14   9.4667   12.0333     85.32
# 4          Rikitea      PF  2022-07-24 09:57:15 -23.1203 -134.9692     73.49
# ..             ...     ...                  ...      ...       ...       ...
# 455            Gat      IL  2022-07-24 10:10:35  31.6100   34.7642     93.40
# 456    Kattivakkam      IN  2022-07-24 10:10:35  13.2167   80.3167     91.49
# 457        Chimore      BO  2022-07-24 10:10:35 -16.9833  -65.1333     69.21
# 458       Baripada      IN  2022-07-24 10:10:36  21.9350   86.7214     85.10
# 459  Clarence Town      AU  2022-07-24 10:10:36 -32.5833  151.7833     57.85
#
#      Humidity  Cloudiness  Wind Speed
# 0         100          75        6.91
# 1          76          95        3.83
# 2          94          31        5.01
# 3          57          99       10.25
# 4          72           6       10.33
# ..        ...         ...         ...
# 455        28           0       14.32
# 456        68         100        3.62
# 457        78          22        0.18
# 458        77         100       10.85
# 459        95          30        1.72
#
# [460 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
#6.3.1 Plot Latitude vs. Temperature

# %%
#Get Data for Plotting

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1658657949.2050278

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
#6.3.3 Plot Latitude vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
#6.3.4 Plot Latitude vs. Wind Speed

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
#6.4.1 Use Linear Regression to Find the Relationship Between Variables

# %%
#Practice Using Linear Regression

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create an equal number of latitudes and temperatures.
lats = [42.5, 43.9, 8.1, 36.8, 79.9, 69.1, 25.7, 15.3, 12.7, 64.5]
temps = [80.5, 75.3, 90.9, 90.0, 40.4, 62.3, 85.4, 79.6, 72.5, 72.0]

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(lats, temps)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -0.45x + 92.94
# The p-value is: 0.011

# %%
# Calculate the regression line "y values" from the slope and intercept.
regress_values = [(lat * slope + intercept) for lat in lats]

# %%
# Import Matplotlib.
import matplotlib.pyplot as plt
# Create a scatter plot of the x and y values.
plt.scatter(lats,temps)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(lats,regress_values,"r")
# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()

# %%
#6.4.2 Find the Correlation Between Latitude and Maximum Temperature

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

# Calculate the regression line "y values" from the slope and intercept.
regress_values = x_values * slope + intercept

# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create a scatter plot of the x and y values.
plt.scatter(x_values,y_values)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(x_values,regress_values,"r")
# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")
plt.title(title)
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [65], in <cell line: 2>()
#       1 # Perform linear regression.
# ----> 2 (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
#       4 # Calculate the regression line "y values" from the slope and intercept.
#       5 regress_values = x_values * slope + intercept
#
# NameError: name 'x_values' is not defined

# %%
#Create a Linear Regression Function

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
#Create the Hemisphere DataFrames

# %%
#create Northern Hemisphere DataFrames from the city_data_df & use loc method
index13 = city_data_df.loc[13]
index13
# Out:
# City                       Xingyi
# Country                        CN
# Date          2022-07-24 09:57:17
# Lat                       24.1877
# Lng                       102.817
# Max Temp                    73.29
# Humidity                       74
# Cloudiness                     69
# Wind Speed                    4.9
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 455     True
# 456     True
# 457    False
# 458     True
# 459    False
# Name: Lat, Length: 460, dtype: bool

# %%
#to return a DataFrame with all data fitting the criteria, for latitudes greater than or equal to 0
city_data_df.loc[(city_data_df["Lat"] >= 0)]
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0    Yellowknife      CA  2022-07-24 09:57:12  62.4560 -114.3525     59.52
# 1          Ambam      CM  2022-07-24 09:57:13   2.3833   11.2833     73.56
# 2           Hilo      US  2022-07-24 09:53:51  19.7297 -155.0900     77.29
# 3          Numan      NG  2022-07-24 09:57:14   9.4667   12.0333     85.32
# 6        Kamenka      RU  2022-07-24 09:57:15  51.3223   42.7678     79.70
# ..           ...     ...                  ...      ...       ...       ...
# 453        Upata      VE  2022-07-24 10:10:34   8.0086  -62.3989     69.21
# 454     Mayfield      US  2022-07-24 10:10:35  36.7417  -88.6367     77.83
# 455          Gat      IL  2022-07-24 10:10:35  31.6100   34.7642     93.40
# 456  Kattivakkam      IN  2022-07-24 10:10:35  13.2167   80.3167     91.49
# 458     Baripada      IN  2022-07-24 10:10:36  21.9350   86.7214     85.10
#
#      Humidity  Cloudiness  Wind Speed
# 0         100          75        6.91
# 1          76          95        3.83
# 2          94          31        5.01
# 3          57          99       10.25
# 6          47          84        8.30
# ..        ...         ...         ...
# 453        97          93        3.76
# 454        89           0        4.61
# 455        28           0       14.32
# 456        68         100        3.62
# 458        77         100       10.85
#
# [317 rows x 9 columns]

# %%
#top 5 rows
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0  Yellowknife      CA  2022-07-24 09:57:12  62.4560 -114.3525     59.52
# 1        Ambam      CM  2022-07-24 09:57:13   2.3833   11.2833     73.56
# 2         Hilo      US  2022-07-24 09:53:51  19.7297 -155.0900     77.29
# 3        Numan      NG  2022-07-24 09:57:14   9.4667   12.0333     85.32
# 6      Kamenka      RU  2022-07-24 09:57:15  51.3223   42.7678     79.70
#
#    Humidity  Cloudiness  Wind Speed
# 0       100          75        6.91
# 1        76          95        3.83
# 2        94          31        5.01
# 3        57          99       10.25
# 6        47          84        8.30

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
#Perform Linear Regression on the Maximum Temperature for the Northern Hemisphere

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
#Perform Linear Regression on the Maximum Temperature for the Southern Hemisphere

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
#^^^The correlation between the latitude and the maximum temperature is strong to very strong because the r-value is less
#than –0.7 for the Northern Hemisphere and greater than 0.7 for the Southern Hemisphere, as shown by the plots here.
#This means that as we approach the equator, 0° latitude, the temperatures become warmer. And when we are further from 
#the equator the temperatures become cooler. Check the r-values for your plots.

# %%
#6.4.3 Find the Correlation Between Latitude and Percent Humidity

# %%
#Perform Linear Regression on the Percent Humidity for the Northern Hemisphere

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
#Perform Linear Regression on the Percent Humidity for the Southern Hemisphere

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
#The correlation between the latitude and percent humidity is very low because the r-value is less than 0.04 for the Northern 
#and Southern Hemispheres for the plots shown here. This means that percent humidity is unpredictable due to changing weather 
#patterns that can increase or decrease percent humidity. Check the r-values for your plots.

# %%
#6.4.4 Find the Correlation Between Latitude and Percent Cloudiness

# %%
#Perform Linear Regression on the Percent Cloudiness for the Northern Hemisphere

# %%
#skilldrill
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the the Northern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,15))

# %%
#Perform Linear Regression on the Percent Cloudiness for the Southern Hemisphere

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
#FINDING The correlation between the latitude and percent cloudiness is very low because the r-value is less than –0.09 for the 
#Northern Hemisphere and less than –0.02 for the Southern Hemisphere for the plots shown here. This means that cloudiness is 
#unpredictable due to changing weather patterns that can increase or decrease percent cloudiness. Check the r-values for your 
#plots.

# %%
#6.4.5 Find the Correlation Between Latitude and Wind Speed

# %%
#Perform Linear Regression on the Wind Speed for the Northern Hemisphere

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
#Perform Linear Regression on the Wind Speed for the Southern Hemisphere

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))

# %%
#FINDING The correlation between the latitude and wind speed is very low because the r-value is less  than –0.07 for the 
#Northern Hemisphere and less than –0.3 for the Southern Hemisphere for the plots shown here. This means that wind speed is 
#unpredictable due to changing weather patterns that can increase or decrease wind speed. Check the r-values for your plots.
