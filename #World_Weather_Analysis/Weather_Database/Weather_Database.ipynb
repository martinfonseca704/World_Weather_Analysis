# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 720

# %%
import requests
requests.__version__
# Out:
# '2.28.0'

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    # print(city) or # print (i, city) 
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
     # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    #print(city_url)
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1 
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append(
            {
                "City": city.title(),
                "Lat": city_lat,
                "Lng": city_lng,
                "Max Temp": city_max_temp,
                "Humidity": city_humidity,
                "Cloudiness": city_clouds,
                "Wind Speed": city_wind,
                "Country": city_country,
                "Weather Description":city_weather_description
             })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | johnson city
# Processing Record 2 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 1 | bria
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | tay ninh
# Processing Record 7 of Set 1 | bogacs
# Processing Record 8 of Set 1 | russell
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 1 | bantou
# Processing Record 12 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | castro
# Processing Record 15 of Set 1 | sao filipe
# Processing Record 16 of Set 1 | terenos
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | hami
# Processing Record 21 of Set 1 | pevek
# Processing Record 22 of Set 1 | heihe
# Processing Record 23 of Set 1 | esperance
# Processing Record 24 of Set 1 | zakamensk
# Processing Record 25 of Set 1 | brae
# Processing Record 26 of Set 1 | namibe
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | tabory
# Processing Record 29 of Set 1 | samarai
# Processing Record 30 of Set 1 | shingu
# Processing Record 31 of Set 1 | wanaka
# Processing Record 32 of Set 1 | mahanoro
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | cap-aux-meules
# Processing Record 37 of Set 1 | digha
# Processing Record 38 of Set 1 | camargo
# Processing Record 39 of Set 1 | khatanga
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | bratsk
# Processing Record 42 of Set 1 | mar del plata
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 44 of Set 1 | bubaque
# Processing Record 45 of Set 1 | bethel
# Processing Record 46 of Set 1 | poum
# Processing Record 47 of Set 1 | rio grande
# Processing Record 48 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 1 | jumla
# Processing Record 50 of Set 1 | pundaguitan
# Processing Record 1 of Set 2 | goure
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | aksarka
# Processing Record 4 of Set 2 | puerto ayacucho
# Processing Record 5 of Set 2 | vao
# Processing Record 6 of Set 2 | vila do maio
# Processing Record 7 of Set 2 | svetlaya
# Processing Record 8 of Set 2 | shambu
# Processing Record 9 of Set 2 | thompson
# Processing Record 10 of Set 2 | yellowknife
# Processing Record 11 of Set 2 | jamestown
# Processing Record 12 of Set 2 | kaitangata
# Processing Record 13 of Set 2 | elat
# Processing Record 14 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 2 | bengkulu
# Processing Record 16 of Set 2 | narsaq
# Processing Record 17 of Set 2 | carnarvon
# Processing Record 18 of Set 2 | cockburn town
# Processing Record 19 of Set 2 | torbay
# Processing Record 20 of Set 2 | port blair
# Processing Record 21 of Set 2 | magadan
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | calama
# Processing Record 24 of Set 2 | hilo
# Processing Record 25 of Set 2 | yar-sale
# Processing Record 26 of Set 2 | leningradskiy
# Processing Record 27 of Set 2 | santa cruz
# Processing Record 28 of Set 2 | marawi
# Processing Record 29 of Set 2 | puerto ayora
# Processing Record 30 of Set 2 | oussouye
# Processing Record 31 of Set 2 | roebourne
# Processing Record 32 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 2 | chokurdakh
# Processing Record 34 of Set 2 | charagua
# Processing Record 35 of Set 2 | barrow
# Processing Record 36 of Set 2 | griffith
# Processing Record 37 of Set 2 | tianpeng
# Processing Record 38 of Set 2 | venosa
# Processing Record 39 of Set 2 | luderitz
# Processing Record 40 of Set 2 | sitka
# Processing Record 41 of Set 2 | qui nhon
# Processing Record 42 of Set 2 | ladario
# Processing Record 43 of Set 2 | saint-philippe
# Processing Record 44 of Set 2 | longyearbyen
# Processing Record 45 of Set 2 | vila
# Processing Record 46 of Set 2 | belle fourche
# Processing Record 47 of Set 2 | hasaki
# Processing Record 48 of Set 2 | sao felix do xingu
# Processing Record 49 of Set 2 | kapaa
# Processing Record 50 of Set 2 | shimoda
# Processing Record 1 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 3 | kayankulam
# Processing Record 3 of Set 3 | mahanje
# Processing Record 4 of Set 3 | tiznit
# Processing Record 5 of Set 3 | arraial do cabo
# Processing Record 6 of Set 3 | comodoro rivadavia
# Processing Record 7 of Set 3 | port elizabeth
# Processing Record 8 of Set 3 | norman wells
# Processing Record 9 of Set 3 | guhagar
# Processing Record 10 of Set 3 | airai
# Processing Record 11 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 3 | port-gentil
# Processing Record 13 of Set 3 | lumphat
# Processing Record 14 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 3 | camacha
# Processing Record 16 of Set 3 | emba
# Processing Record 17 of Set 3 | ketchikan
# Processing Record 18 of Set 3 | pisco
# Processing Record 19 of Set 3 | bluff
# Processing Record 20 of Set 3 | vostok
# Processing Record 21 of Set 3 | roald
# Processing Record 22 of Set 3 | shaunavon
# Processing Record 23 of Set 3 | meulaboh
# Processing Record 24 of Set 3 | maceio
# Processing Record 25 of Set 3 | yining
# Processing Record 26 of Set 3 | komsomolskiy
# Processing Record 27 of Set 3 | ermoupolis
# Processing Record 28 of Set 3 | atuona
# Processing Record 29 of Set 3 | det udom
# Processing Record 30 of Set 3 | porterville
# Processing Record 31 of Set 3 | zhigansk
# Processing Record 32 of Set 3 | vila velha
# Processing Record 33 of Set 3 | nueva loja
# Processing Record 34 of Set 3 | vanimo
# Processing Record 35 of Set 3 | okhotsk
# Processing Record 36 of Set 3 | harper
# Processing Record 37 of Set 3 | pacific grove
# Processing Record 38 of Set 3 | abu dhabi
# Processing Record 39 of Set 3 | praia da vitoria
# Processing Record 40 of Set 3 | mount isa
# Processing Record 41 of Set 3 | pangai
# Processing Record 42 of Set 3 | tikhmenevo
# City not found. Skipping...
# Processing Record 43 of Set 3 | carutapera
# Processing Record 44 of Set 3 | avarua
# Processing Record 45 of Set 3 | flinders
# Processing Record 46 of Set 3 | grindavik
# Processing Record 47 of Set 3 | souillac
# Processing Record 48 of Set 3 | geraldton
# Processing Record 49 of Set 3 | la rioja
# Processing Record 50 of Set 3 | bayan
# Processing Record 1 of Set 4 | qasigiannguit
# Processing Record 2 of Set 4 | henties bay
# Processing Record 3 of Set 4 | nantucket
# Processing Record 4 of Set 4 | constitucion
# Processing Record 5 of Set 4 | georgetown
# Processing Record 6 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 4 | nanortalik
# Processing Record 8 of Set 4 | east london
# Processing Record 9 of Set 4 | sargur
# Processing Record 10 of Set 4 | pangnirtung
# Processing Record 11 of Set 4 | cape town
# Processing Record 12 of Set 4 | cabo san lucas
# Processing Record 13 of Set 4 | ponta do sol
# Processing Record 14 of Set 4 | santa maria
# Processing Record 15 of Set 4 | yerbogachen
# Processing Record 16 of Set 4 | laguna
# Processing Record 17 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 4 | provideniya
# Processing Record 19 of Set 4 | isangel
# Processing Record 20 of Set 4 | chon daen
# Processing Record 21 of Set 4 | xichang
# Processing Record 22 of Set 4 | guerrero negro
# Processing Record 23 of Set 4 | hithadhoo
# Processing Record 24 of Set 4 | remerschen
# Processing Record 25 of Set 4 | codrington
# Processing Record 26 of Set 4 | green river
# Processing Record 27 of Set 4 | fukue
# Processing Record 28 of Set 4 | dongsheng
# Processing Record 29 of Set 4 | bure
# Processing Record 30 of Set 4 | belomorsk
# Processing Record 31 of Set 4 | asau
# Processing Record 32 of Set 4 | buala
# Processing Record 33 of Set 4 | jieshi
# Processing Record 34 of Set 4 | ahipara
# Processing Record 35 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 36 of Set 4 | grand gaube
# Processing Record 37 of Set 4 | naifaru
# Processing Record 38 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 39 of Set 4 | taoudenni
# Processing Record 40 of Set 4 | podor
# Processing Record 41 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 4 | tiksi
# Processing Record 43 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 4 | sukumo
# Processing Record 45 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 46 of Set 4 | mana
# Processing Record 47 of Set 4 | vila franca do campo
# Processing Record 48 of Set 4 | bengbu
# Processing Record 49 of Set 4 | erzin
# Processing Record 50 of Set 4 | tucupita
# Processing Record 1 of Set 5 | nuevo progreso
# Processing Record 2 of Set 5 | mildura
# Processing Record 3 of Set 5 | honningsvag
# Processing Record 4 of Set 5 | baykit
# Processing Record 5 of Set 5 | okitipupa
# Processing Record 6 of Set 5 | morogoro
# Processing Record 7 of Set 5 | saint-marc-des-carrieres
# Processing Record 8 of Set 5 | izhevsk
# Processing Record 9 of Set 5 | korla
# Processing Record 10 of Set 5 | nikolskoye
# Processing Record 11 of Set 5 | dikson
# Processing Record 12 of Set 5 | saskylakh
# Processing Record 13 of Set 5 | xam nua
# Processing Record 14 of Set 5 | robertsport
# Processing Record 15 of Set 5 | aklavik
# Processing Record 16 of Set 5 | berdigestyakh
# Processing Record 17 of Set 5 | san-pedro
# Processing Record 18 of Set 5 | tuatapere
# Processing Record 19 of Set 5 | chicama
# Processing Record 20 of Set 5 | boende
# Processing Record 21 of Set 5 | kieta
# Processing Record 22 of Set 5 | san patricio
# Processing Record 23 of Set 5 | kananga
# Processing Record 24 of Set 5 | butaritari
# Processing Record 25 of Set 5 | baruun-urt
# Processing Record 26 of Set 5 | fortuna
# Processing Record 27 of Set 5 | hella
# Processing Record 28 of Set 5 | porto nacional
# Processing Record 29 of Set 5 | upernavik
# Processing Record 30 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 5 | sokolo
# Processing Record 32 of Set 5 | tasiilaq
# Processing Record 33 of Set 5 | foz
# Processing Record 34 of Set 5 | pimenta bueno
# Processing Record 35 of Set 5 | high rock
# Processing Record 36 of Set 5 | paracuru
# Processing Record 37 of Set 5 | ayorou
# Processing Record 38 of Set 5 | ribeira grande
# Processing Record 39 of Set 5 | uvira
# Processing Record 40 of Set 5 | abhar
# Processing Record 41 of Set 5 | victoria
# Processing Record 42 of Set 5 | clyde river
# Processing Record 43 of Set 5 | muros
# Processing Record 44 of Set 5 | victoria point
# Processing Record 45 of Set 5 | polson
# Processing Record 46 of Set 5 | sinnamary
# Processing Record 47 of Set 5 | fairbanks
# Processing Record 48 of Set 5 | lahad datu
# Processing Record 49 of Set 5 | kloulklubed
# Processing Record 50 of Set 5 | nileshwar
# Processing Record 1 of Set 6 | katsuura
# Processing Record 2 of Set 6 | bandarbeyla
# Processing Record 3 of Set 6 | qingdao
# Processing Record 4 of Set 6 | dingle
# Processing Record 5 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 6 | husavik
# Processing Record 7 of Set 6 | inhambane
# Processing Record 8 of Set 6 | port keats
# Processing Record 9 of Set 6 | jurm
# Processing Record 10 of Set 6 | tuktoyaktuk
# Processing Record 11 of Set 6 | dunedin
# Processing Record 12 of Set 6 | victor harbor
# Processing Record 13 of Set 6 | darya khan
# Processing Record 14 of Set 6 | lebu
# Processing Record 15 of Set 6 | arlit
# Processing Record 16 of Set 6 | garden city
# Processing Record 17 of Set 6 | alofi
# Processing Record 18 of Set 6 | coquimbo
# Processing Record 19 of Set 6 | karasjok
# Processing Record 20 of Set 6 | bambous virieux
# Processing Record 21 of Set 6 | pierre
# Processing Record 22 of Set 6 | koungou
# Processing Record 23 of Set 6 | rockport
# Processing Record 24 of Set 6 | kirkwood
# Processing Record 25 of Set 6 | preobrazheniye
# Processing Record 26 of Set 6 | chuy
# Processing Record 27 of Set 6 | beloha
# Processing Record 28 of Set 6 | parabel
# Processing Record 29 of Set 6 | yinchuan
# Processing Record 30 of Set 6 | saint george
# Processing Record 31 of Set 6 | bamiantong
# Processing Record 32 of Set 6 | sembe
# Processing Record 33 of Set 6 | sabang
# Processing Record 34 of Set 6 | udalguri
# Processing Record 35 of Set 6 | severo-kurilsk
# Processing Record 36 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 37 of Set 6 | salinopolis
# Processing Record 38 of Set 6 | zhicheng
# Processing Record 39 of Set 6 | lorengau
# Processing Record 40 of Set 6 | gat
# Processing Record 41 of Set 6 | port moresby
# Processing Record 42 of Set 6 | stornoway
# Processing Record 43 of Set 6 | vardo
# Processing Record 44 of Set 6 | vagur
# Processing Record 45 of Set 6 | egvekinot
# Processing Record 46 of Set 6 | iqaluit
# Processing Record 47 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 6 | port hardy
# Processing Record 49 of Set 6 | trofors
# Processing Record 50 of Set 6 | paamiut
# Processing Record 1 of Set 7 | janauba
# Processing Record 2 of Set 7 | lagoa
# Processing Record 3 of Set 7 | fairview
# Processing Record 4 of Set 7 | te anau
# Processing Record 5 of Set 7 | batemans bay
# Processing Record 6 of Set 7 | lavrentiya
# Processing Record 7 of Set 7 | hamilton
# Processing Record 8 of Set 7 | fujin
# Processing Record 9 of Set 7 | zuwarah
# Processing Record 10 of Set 7 | hirara
# Processing Record 11 of Set 7 | malakal
# Processing Record 12 of Set 7 | teguise
# Processing Record 13 of Set 7 | marigot
# Processing Record 14 of Set 7 | urusha
# Processing Record 15 of Set 7 | pontian kecil
# Processing Record 16 of Set 7 | asfi
# Processing Record 17 of Set 7 | traverse city
# Processing Record 18 of Set 7 | nioro
# Processing Record 19 of Set 7 | sisimiut
# Processing Record 20 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 7 | tucuman
# Processing Record 22 of Set 7 | kismayo
# Processing Record 23 of Set 7 | nome
# Processing Record 24 of Set 7 | merauke
# Processing Record 25 of Set 7 | lompoc
# Processing Record 26 of Set 7 | san andres
# Processing Record 27 of Set 7 | taksimo
# Processing Record 28 of Set 7 | naze
# Processing Record 29 of Set 7 | broome
# Processing Record 30 of Set 7 | dudinka
# Processing Record 31 of Set 7 | dengzhou
# Processing Record 32 of Set 7 | launceston
# Processing Record 33 of Set 7 | santa barbara
# Processing Record 34 of Set 7 | pathein
# Processing Record 35 of Set 7 | kemi
# Processing Record 36 of Set 7 | avera
# Processing Record 37 of Set 7 | chara
# Processing Record 38 of Set 7 | fairhope
# Processing Record 39 of Set 7 | necochea
# Processing Record 40 of Set 7 | ribeira brava
# Processing Record 41 of Set 7 | yumen
# Processing Record 42 of Set 7 | ixtapa
# Processing Record 43 of Set 7 | cherskiy
# Processing Record 44 of Set 7 | tessalit
# Processing Record 45 of Set 7 | quatre cocos
# Processing Record 46 of Set 7 | vreed en hoop
# City not found. Skipping...
# Processing Record 47 of Set 7 | orsha
# Processing Record 48 of Set 7 | middlesex
# Processing Record 49 of Set 7 | labuhan
# Processing Record 50 of Set 7 | opuwo
# Processing Record 1 of Set 8 | kasongo-lunda
# Processing Record 2 of Set 8 | le pradet
# Processing Record 3 of Set 8 | bozuyuk
# Processing Record 4 of Set 8 | ancud
# Processing Record 5 of Set 8 | sterling
# Processing Record 6 of Set 8 | perth
# Processing Record 7 of Set 8 | dolores hidalgo
# Processing Record 8 of Set 8 | kruisfontein
# Processing Record 9 of Set 8 | guipavas
# Processing Record 10 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 11 of Set 8 | yaransk
# Processing Record 12 of Set 8 | solnechnyy
# Processing Record 13 of Set 8 | kavieng
# Processing Record 14 of Set 8 | faanui
# Processing Record 15 of Set 8 | atambua
# Processing Record 16 of Set 8 | steinbach
# Processing Record 17 of Set 8 | kamenka
# Processing Record 18 of Set 8 | doka
# Processing Record 19 of Set 8 | tubuala
# Processing Record 20 of Set 8 | tapah
# Processing Record 21 of Set 8 | maple creek
# Processing Record 22 of Set 8 | skjervoy
# Processing Record 23 of Set 8 | sorong
# Processing Record 24 of Set 8 | soe
# Processing Record 25 of Set 8 | sitio novo do tocantins
# Processing Record 26 of Set 8 | wadena
# Processing Record 27 of Set 8 | mandalgovi
# Processing Record 28 of Set 8 | ongandjera
# Processing Record 29 of Set 8 | ayagoz
# Processing Record 30 of Set 8 | wielun
# Processing Record 31 of Set 8 | chalmette
# Processing Record 32 of Set 8 | huarmey
# Processing Record 33 of Set 8 | la ronge
# Processing Record 34 of Set 8 | okha
# Processing Record 35 of Set 8 | richards bay
# Processing Record 36 of Set 8 | ocean city
# Processing Record 37 of Set 8 | ossora
# Processing Record 38 of Set 8 | bintulu
# Processing Record 39 of Set 8 | frutigen
# Processing Record 40 of Set 8 | sao joao da barra
# Processing Record 41 of Set 8 | bilma
# Processing Record 42 of Set 8 | omboue
# Processing Record 43 of Set 8 | betare oya
# Processing Record 44 of Set 8 | guiong
# Processing Record 45 of Set 8 | ciudad bolivar
# Processing Record 46 of Set 8 | ust-tsilma
# Processing Record 47 of Set 8 | beringovskiy
# Processing Record 48 of Set 8 | valparaiso
# Processing Record 49 of Set 8 | halifax
# Processing Record 50 of Set 8 | port lincoln
# Processing Record 1 of Set 9 | nemencine
# Processing Record 2 of Set 9 | bowen
# Processing Record 3 of Set 9 | sur
# Processing Record 4 of Set 9 | fontem
# Processing Record 5 of Set 9 | manicore
# Processing Record 6 of Set 9 | sinjai
# Processing Record 7 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 9 | mount gambier
# Processing Record 9 of Set 9 | kemijarvi
# Processing Record 10 of Set 9 | nichinan
# Processing Record 11 of Set 9 | westport
# Processing Record 12 of Set 9 | ilulissat
# Processing Record 13 of Set 9 | muzaffarabad
# Processing Record 14 of Set 9 | rize
# Processing Record 15 of Set 9 | huilong
# Processing Record 16 of Set 9 | formosa do rio preto
# Processing Record 17 of Set 9 | tororo
# Processing Record 18 of Set 9 | pacifica
# Processing Record 19 of Set 9 | alice springs
# Processing Record 20 of Set 9 | santa isabel do rio negro
# Processing Record 21 of Set 9 | aras
# Processing Record 22 of Set 9 | saldanha
# Processing Record 23 of Set 9 | along
# Processing Record 24 of Set 9 | autlan
# City not found. Skipping...
# Processing Record 25 of Set 9 | vaitape
# Processing Record 26 of Set 9 | xifeng
# Processing Record 27 of Set 9 | ucluelet
# Processing Record 28 of Set 9 | karratha
# Processing Record 29 of Set 9 | nha trang
# Processing Record 30 of Set 9 | el retorno
# Processing Record 31 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 9 | van buren
# Processing Record 33 of Set 9 | bardiyah
# Processing Record 34 of Set 9 | zolotinka
# City not found. Skipping...
# Processing Record 35 of Set 9 | acajutla
# Processing Record 36 of Set 9 | lakatoro
# Processing Record 37 of Set 9 | mayor pablo lagerenza
# Processing Record 38 of Set 9 | peniche
# Processing Record 39 of Set 9 | bacuit
# City not found. Skipping...
# Processing Record 40 of Set 9 | najran
# Processing Record 41 of Set 9 | coihaique
# Processing Record 42 of Set 9 | zwedru
# Processing Record 43 of Set 9 | madang
# Processing Record 44 of Set 9 | bhag
# Processing Record 45 of Set 9 | lafayette
# Processing Record 46 of Set 9 | christchurch
# Processing Record 47 of Set 9 | cayenne
# Processing Record 48 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 49 of Set 9 | kupang
# Processing Record 50 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 1 of Set 10 | marion
# Processing Record 2 of Set 10 | eureka
# Processing Record 3 of Set 10 | guaymas
# Processing Record 4 of Set 10 | kabo
# Processing Record 5 of Set 10 | abonnema
# Processing Record 6 of Set 10 | bakchar
# Processing Record 7 of Set 10 | sri aman
# Processing Record 8 of Set 10 | mahebourg
# Processing Record 9 of Set 10 | haines junction
# Processing Record 10 of Set 10 | naryan-mar
# Processing Record 11 of Set 10 | ola
# Processing Record 12 of Set 10 | hambantota
# Processing Record 13 of Set 10 | jardim
# Processing Record 14 of Set 10 | severomuysk
# Processing Record 15 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 10 | tigil
# Processing Record 17 of Set 10 | urucui
# Processing Record 18 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 19 of Set 10 | sola
# Processing Record 20 of Set 10 | kulhudhuffushi
# Processing Record 21 of Set 10 | namatanai
# Processing Record 22 of Set 10 | the pas
# Processing Record 23 of Set 10 | mmabatho
# Processing Record 24 of Set 10 | vestmanna
# Processing Record 25 of Set 10 | baherden
# Processing Record 26 of Set 10 | chapais
# Processing Record 27 of Set 10 | avila
# Processing Record 28 of Set 10 | chenghai
# Processing Record 29 of Set 10 | shwebo
# Processing Record 30 of Set 10 | kangaatsiaq
# Processing Record 31 of Set 10 | jertih
# Processing Record 32 of Set 10 | otjimbingwe
# Processing Record 33 of Set 10 | phetchaburi
# Processing Record 34 of Set 10 | itaituba
# Processing Record 35 of Set 10 | kurara
# Processing Record 36 of Set 10 | ham lake
# Processing Record 37 of Set 10 | port hedland
# Processing Record 38 of Set 10 | kabanjahe
# Processing Record 39 of Set 10 | nurota
# Processing Record 40 of Set 10 | taltal
# Processing Record 41 of Set 10 | aksu
# Processing Record 42 of Set 10 | myitkyina
# Processing Record 43 of Set 10 | banamba
# Processing Record 44 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 45 of Set 10 | chudniv
# Processing Record 46 of Set 10 | port hueneme
# Processing Record 47 of Set 10 | lagos
# Processing Record 48 of Set 10 | ponta delgada
# Processing Record 49 of Set 10 | george town
# Processing Record 50 of Set 10 | stolin
# Processing Record 1 of Set 11 | hanstholm
# Processing Record 2 of Set 11 | lata
# Processing Record 3 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 11 | cebuano
# Processing Record 5 of Set 11 | dzaoudzi
# Processing Record 6 of Set 11 | maniitsoq
# Processing Record 7 of Set 11 | jacareacanga
# Processing Record 8 of Set 11 | klaksvik
# Processing Record 9 of Set 11 | gunib
# Processing Record 10 of Set 11 | tobol
# Processing Record 11 of Set 11 | buraydah
# Processing Record 12 of Set 11 | serebryansk
# Processing Record 13 of Set 11 | shreveport
# Processing Record 14 of Set 11 | saint-pierre
# Processing Record 15 of Set 11 | diffa
# Processing Record 16 of Set 11 | whitehorse
# Processing Record 17 of Set 11 | brownsville
# Processing Record 18 of Set 11 | hualmay
# Processing Record 19 of Set 11 | yerofey pavlovich
# Processing Record 20 of Set 11 | ulaangom
# Processing Record 21 of Set 11 | mitchell
# Processing Record 22 of Set 11 | butembo
# Processing Record 23 of Set 11 | khani
# Processing Record 24 of Set 11 | stockbridge
# Processing Record 25 of Set 11 | saint-doulchard
# Processing Record 26 of Set 11 | le robert
# Processing Record 27 of Set 11 | salalah
# Processing Record 28 of Set 11 | sile
# Processing Record 29 of Set 11 | saint leonard
# Processing Record 30 of Set 11 | general roca
# Processing Record 31 of Set 11 | robinson
# Processing Record 32 of Set 11 | galle
# Processing Record 33 of Set 11 | nelson bay
# Processing Record 34 of Set 11 | ust-nera
# Processing Record 35 of Set 11 | ginir
# Processing Record 36 of Set 11 | hailey
# Processing Record 37 of Set 11 | daru
# Processing Record 38 of Set 11 | sibolga
# Processing Record 39 of Set 11 | kudahuvadhoo
# Processing Record 40 of Set 11 | santa rosalia
# Processing Record 41 of Set 11 | andenes
# Processing Record 42 of Set 11 | mackay
# Processing Record 43 of Set 11 | cordoba
# Processing Record 44 of Set 11 | mariental
# Processing Record 45 of Set 11 | shubarshi
# Processing Record 46 of Set 11 | saleilua
# City not found. Skipping...
# Processing Record 47 of Set 11 | dzilam gonzalez
# Processing Record 48 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 49 of Set 11 | iki-burul
# Processing Record 50 of Set 11 | tura
# Processing Record 1 of Set 12 | banda aceh
# Processing Record 2 of Set 12 | marsala
# Processing Record 3 of Set 12 | kushima
# Processing Record 4 of Set 12 | arman
# Processing Record 5 of Set 12 | half moon bay
# Processing Record 6 of Set 12 | oudtshoorn
# Processing Record 7 of Set 12 | gambo
# Processing Record 8 of Set 12 | kahului
# Processing Record 9 of Set 12 | pamekasan
# Processing Record 10 of Set 12 | california city
# Processing Record 11 of Set 12 | seoul
# Processing Record 12 of Set 12 | kyaka
# Processing Record 13 of Set 12 | kendari
# Processing Record 14 of Set 12 | ode
# Processing Record 15 of Set 12 | ruteng
# Processing Record 16 of Set 12 | kashi
# Processing Record 17 of Set 12 | pasni
# Processing Record 18 of Set 12 | cervo
# Processing Record 19 of Set 12 | raudeberg
# Processing Record 20 of Set 12 | riobamba
# Processing Record 21 of Set 12 | bonavista
# Processing Record 22 of Set 12 | nishihara
# Processing Record 23 of Set 12 | shentala
# Processing Record 24 of Set 12 | cap malheureux
# Processing Record 25 of Set 12 | barcelos
# Processing Record 26 of Set 12 | chaoyang
# Processing Record 27 of Set 12 | ermioni
# Processing Record 28 of Set 12 | shirdi
# Processing Record 29 of Set 12 | empalme
# Processing Record 30 of Set 12 | lewisporte
# Processing Record 31 of Set 12 | tonj
# Processing Record 32 of Set 12 | fare
# Processing Record 33 of Set 12 | nova ushytsya
# Processing Record 34 of Set 12 | ust-ishim
# Processing Record 35 of Set 12 | mehamn
# Processing Record 36 of Set 12 | inuvik
# Processing Record 37 of Set 12 | nidzica
# Processing Record 38 of Set 12 | patea
# Processing Record 39 of Set 12 | zhangjiakou
# Processing Record 40 of Set 12 | kirakira
# Processing Record 41 of Set 12 | aykhal
# Processing Record 42 of Set 12 | kintampo
# Processing Record 43 of Set 12 | marrakesh
# Processing Record 44 of Set 12 | pontes e lacerda
# Processing Record 45 of Set 12 | smithers
# Processing Record 46 of Set 12 | yangambi
# Processing Record 47 of Set 12 | methoni
# Processing Record 48 of Set 12 | biltine
# Processing Record 49 of Set 12 | manokwari
# Processing Record 50 of Set 12 | santa catalina
# Processing Record 1 of Set 13 | kazanskoye
# Processing Record 2 of Set 13 | sept-iles
# Processing Record 3 of Set 13 | cidreira
# Processing Record 4 of Set 13 | havelock
# Processing Record 5 of Set 13 | nchelenge
# Processing Record 6 of Set 13 | tahe
# Processing Record 7 of Set 13 | swan hill
# Processing Record 8 of Set 13 | moose factory
# Processing Record 9 of Set 13 | oktyabrskiy
# Processing Record 10 of Set 13 | monroe
# Processing Record 11 of Set 13 | dwarka
# Processing Record 12 of Set 13 | tsuruga
# Processing Record 13 of Set 13 | oskarshamn
# Processing Record 14 of Set 13 | juneau
# Processing Record 15 of Set 13 | kiunga
# Processing Record 16 of Set 13 | shimanovsk
# Processing Record 17 of Set 13 | mogadishu
# Processing Record 18 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 13 | sindand
# City not found. Skipping...
# Processing Record 20 of Set 13 | lamu
# Processing Record 21 of Set 13 | sueca
# Processing Record 22 of Set 13 | zelenoborsk
# Processing Record 23 of Set 13 | talnakh
# Processing Record 24 of Set 13 | santiago
# Processing Record 25 of Set 13 | leshukonskoye
# Processing Record 26 of Set 13 | chegem
# Processing Record 27 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 13 | barsovo
# Processing Record 29 of Set 13 | biak
# Processing Record 30 of Set 13 | lipin bor
# Processing Record 31 of Set 13 | tambura
# Processing Record 32 of Set 13 | moussoro
# Processing Record 33 of Set 13 | bassar
# Processing Record 34 of Set 13 | amapa
# Processing Record 35 of Set 13 | rawson
# Processing Record 36 of Set 13 | college
# Processing Record 37 of Set 13 | bagdarin
# Processing Record 38 of Set 13 | curillo
# Processing Record 39 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 13 | riachao das neves
# Processing Record 41 of Set 13 | bochum
# Processing Record 42 of Set 13 | luanda
# Processing Record 43 of Set 13 | lewistown
# Processing Record 44 of Set 13 | berbera
# Processing Record 45 of Set 13 | berlevag
# Processing Record 46 of Set 13 | ostersund
# Processing Record 47 of Set 13 | yarim
# Processing Record 48 of Set 13 | sellye
# Processing Record 49 of Set 13 | okato
# Processing Record 50 of Set 13 | cabedelo
# Processing Record 1 of Set 14 | flic en flac
# Processing Record 2 of Set 14 | zhangye
# Processing Record 3 of Set 14 | barahona
# Processing Record 4 of Set 14 | usinsk
# Processing Record 5 of Set 14 | pitkyaranta
# Processing Record 6 of Set 14 | letlhakane
# Processing Record 7 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 8 of Set 14 | manggar
# Processing Record 9 of Set 14 | khilok
# Processing Record 10 of Set 14 | ambon
# Processing Record 11 of Set 14 | kodinsk
# Processing Record 12 of Set 14 | jimenez
# Processing Record 13 of Set 14 | almaty
# Processing Record 14 of Set 14 | luzon
# Processing Record 15 of Set 14 | atherton
# Processing Record 16 of Set 14 | chillicothe
# Processing Record 17 of Set 14 | rjukan
# Processing Record 18 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 19 of Set 14 | san cristobal
# Processing Record 20 of Set 14 | sakaiminato
# Processing Record 21 of Set 14 | nur
# Processing Record 22 of Set 14 | chalus
# Processing Record 23 of Set 14 | udachnyy
# Processing Record 24 of Set 14 | morehead
# Processing Record 25 of Set 14 | agartala
# Processing Record 26 of Set 14 | cacoal
# Processing Record 27 of Set 14 | cristalina
# Processing Record 28 of Set 14 | high level
# Processing Record 29 of Set 14 | ituni
# City not found. Skipping...
# Processing Record 30 of Set 14 | erenhot
# Processing Record 31 of Set 14 | oyotun
# Processing Record 32 of Set 14 | denpasar
# Processing Record 33 of Set 14 | jomalig
# City not found. Skipping...
# Processing Record 34 of Set 14 | jasper
# Processing Record 35 of Set 14 | anshun
# Processing Record 36 of Set 14 | ribas do rio pardo
# Processing Record 37 of Set 14 | biarritz
# Processing Record 38 of Set 14 | oranjestad
# Processing Record 39 of Set 14 | axim
# Processing Record 40 of Set 14 | alugan
# Processing Record 41 of Set 14 | alzamay
# Processing Record 42 of Set 14 | jodhpur
# Processing Record 43 of Set 14 | faya
# Processing Record 44 of Set 14 | uhersky brod
# Processing Record 45 of Set 14 | marzuq
# Processing Record 46 of Set 14 | puqi
# Processing Record 47 of Set 14 | alekseyevskaya
# Processing Record 48 of Set 14 | portland
# Processing Record 49 of Set 14 | bundibugyo
# Processing Record 50 of Set 14 | nhulunbuy
# Processing Record 1 of Set 15 | caravelas
# Processing Record 2 of Set 15 | bathsheba
# Processing Record 3 of Set 15 | iznoski
# Processing Record 4 of Set 15 | vieux fort
# Processing Record 5 of Set 15 | olafsvik
# Processing Record 6 of Set 15 | pemangkat
# Processing Record 7 of Set 15 | kukushtan
# Processing Record 8 of Set 15 | coromandel
# Processing Record 9 of Set 15 | burhar
# Processing Record 10 of Set 15 | cintalapa
# Processing Record 11 of Set 15 | baisha
# Processing Record 12 of Set 15 | muyezerskiy
# Processing Record 13 of Set 15 | koungheul
# Processing Record 14 of Set 15 | golynki
# Processing Record 15 of Set 15 | kaduna
# Processing Record 16 of Set 15 | adrar
# Processing Record 17 of Set 15 | neustadt
# Processing Record 18 of Set 15 | kholodnyy
# Processing Record 19 of Set 15 | mezen
# Processing Record 20 of Set 15 | svarstad
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
#city_data_df.columns
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Johnson City  36.3134  -82.3535     75.43        73          20
# 1          Bria   6.5423   21.9863     66.27        98         100
# 2    Bredasdorp -34.5322   20.0403     55.74        62          27
# 3   Port Alfred -33.5906   26.8910     65.17        61           0
# 4      Tay Ninh  11.3000  106.1000     87.22        66           5
# 5        Bogacs  47.9000   20.5333     68.05        68          79
# 6       Russell  32.3502  -85.1999     82.90        74           0
# 7   New Norfolk -42.7826  147.0587     48.92        45          71
# 8        Bantou  26.2151  117.4893     95.86        47          36
# 9     Busselton -33.6500  115.3333     60.66        61          90
#
#    Wind Speed Country Weather Description
# 0        0.00      US          few clouds
# 1        1.25      CF     overcast clouds
# 2       11.68      ZA    scattered clouds
# 3        4.00      ZA           clear sky
# 4        6.49      VN           clear sky
# 5        4.88      HU       broken clouds
# 6        0.00      US           clear sky
# 7        7.20      AU       broken clouds
# 8        1.88      CN    scattered clouds
# 9       21.99      AU     overcast clouds

# %%
#reorder columns
new_column_order = [ "City","Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Johnson City      US  36.3134  -82.3535     75.43        73          20
# 1          Bria      CF   6.5423   21.9863     66.27        98         100
# 2    Bredasdorp      ZA -34.5322   20.0403     55.74        62          27
# 3   Port Alfred      ZA -33.5906   26.8910     65.17        61           0
# 4      Tay Ninh      VN  11.3000  106.1000     87.22        66           5
# 5        Bogacs      HU  47.9000   20.5333     68.05        68          79
# 6       Russell      US  32.3502  -85.1999     82.90        74           0
# 7   New Norfolk      AU -42.7826  147.0587     48.92        45          71
# 8        Bantou      CN  26.2151  117.4893     95.86        47          36
# 9     Busselton      AU -33.6500  115.3333     60.66        61          90
#
#    Wind Speed Weather Description
# 0        0.00          few clouds
# 1        1.25     overcast clouds
# 2       11.68    scattered clouds
# 3        4.00           clear sky
# 4        6.49           clear sky
# 5        4.88       broken clouds
# 6        0.00           clear sky
# 7        7.20       broken clouds
# 8        1.88    scattered clouds
# 9       21.99     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
